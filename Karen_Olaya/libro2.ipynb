# %%
class Libro:
  def __init__ (self, titulo, precio):    #Constructor
    self .__titulo = titulo     #Atributo   __ que es privada
    self .__precio = precio

    # Construcción de METOTDOS
    # getter, devolver el valor de el atributo solicitado

  def get_titulo(self): #Idenetifica que va a devolver un   valor y solo lo muestrta
    return self.__titulo
  def get_precio(self):
    return self.__precio
      # Realizaremos un metod que me muestre los dos metodos
  def mostrar_info(self):
     print(f"El titulo es: {self.__titulo}, y el precio es: {self.__precio}\n")

 # Vamos a crear un metodo para cambiar el precio
 # Utilizamos SETTER (set), para realizar el cambio de el valor contenido en el
 #atributo

  def set__precio(self, nuevo_precio):
   if isinstance(nuevo_precio, (int , float)):
    self .__precio = nuevo_precio

   else:
    print("Recuerde debe ingresar un número valido")
    # En el siguiente en el siguiente vamos a cambiar el valor del atributo titulo utilizando set
  def set_titulo(self, nuevo_titulo):
    if isinstance(nuevo_titulo, str) and len(nuevo_titulo) >  0:       #Debe de ser string y tener el menos una letra
     self .__titulo = nuevo_titulo  #ActUalizar el atributo con el nuevo valor

def main():
  #Aqui invoco los metoodos
  print("======= ESTIMADO APRENDIZ BIENVENIDO AL PROGEMA DE LIBRO=====\n")

#VAMOS A CREAR 2 OBJETOS , UNO ES HTML, Y PRECIO 200000
#EL SEGUNDO LIBRO SERA JAVASCRIPT, Y PRECIO 186000

  Libro1 =Libro("Html",200000)
  Libro2 =Libro("Javascript",186000)

#Ahora vamos a mostrar los valores iniciales del libro1 con metodos separados
  print("\nINFORMACION DE PRIMER LIBRO METODO SEPARADO")
  print(f"El tituo  es: {Libro1.get_titulo()}")
  print(f"El precio es: {Libro1.get_precio()}")

  #Vamos a mostrar lo anterior pero con todo el metodo mostrado
  print("\nINFORMACION DEL PRIMER LIBRO UN METODO")
  Libro1.mostrar_info()

#Ahora vamos actualizar el precio del libro
  print("\nACTUALIZACION DEL PRECIO DEL PRIMER LIBRO ")
  nuevo_precio = float(input("Ingrese el nuevo precio:"))
  Libro1.set__precio(nuevo_precio)

  print("El nuevo precio actualizado del libro es")
  Libro1.mostrar_info()


 #Ahora vamos actualizar el nombre  del libro
  print("\nACTUALIZACION DEL PRIMER LIBRO ")
  nuevo_titulo = input("Ingrese el nuevo titulo:")
  Libro1.set_titulo(nuevo_titulo)

  print("El nuevo nombre actualizado del libro1 es")
  print(Libro1.get_titulo())

  print("\nlos datos actualizados del libro1 son")
  Libro1.mostrar_info()
if __name__ == "__main__":
  main()
# Out:
# ======= ESTIMADO APRENDIZ BIENVENIDO AL PROGEMA DE LIBRO=====
#
#
# INFORMACION DE PRIMER LIBRO METODO SEPARADO
# El tituo  es: Html
# El precio es: 200000
#
# INFORMACION DEL PRIMER LIBRO UN METODO
# El titulo es: Html, y el precio es: 200000
#
#
# ACTUALIZACION DEL PRECIO DEL PRIMER LIBRO
